# %% [markdown]
# # Visualize and Analyze the data

# %%
import os
os.chdir('../saliency_model/')

import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
(summary, context, model) = pickle.load(open( "19-01-31_results.p", "rb"))

# %%
context = np.array(context)
model = np.array(model)

# %%
nss_table = summary[:,:,0]
print(np.shape(nss_table))
sim_table = summary[:,:,1]
ig_table = summary[:,:,2]
auc_table = summary[:,:,3]
# Out:
# (5, 15)

# %%
plt.plot(nss_table)
plt.xlim(0,4)
plt.xticks([0,1,2,3,4], context)
plt.title("NSS for all models")
plt.legend(model, bbox_to_anchor = (1.1,1.05));

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), sharey='row')

ax[0].plot(nss_table[:, [0,2,4,7,9,11,13,6]])
ax[0].set_xlim([0,6])
ax[0].set_xticks([0,1,2,3,4])
ax[0].set_xticklabels(context)
ax[0].set_title("NSS for all models without face feature")
ax[0].legend([model[i] for i in [0,2,4,7,9,11,13,6]], loc='best');

ax[1].plot(nss_table[:, [1,3,5,8,10,12,14,6]])
ax[1].set_xlim([0,6])
ax[1].set_xticks([0,1,2,3,4])
ax[1].set_xticklabels(context)
ax[1].set_title("NSS for all models with face feature")
ax[1].legend([model[i] for i in [1,3,5,8,10,12,14,6]], loc='best');

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), sharey='row')

ax[0].plot(sim_table[:, [0,2,4,7,9,11,13,6]])
ax[0].set_xlim([0,6])
ax[0].set_xticks([0,1,2,3,4])
ax[0].set_xticklabels(context)
ax[0].set_title("SIM for all models without face feature")
ax[0].legend([model[i] for i in [0,2,4,7,9,11,13,6]], loc='best');

ax[1].plot(sim_table[:, [1,3,5,8,10,12,14]])
ax[1].set_xlim([0,6])
ax[1].set_xticks([0,1,2,3,4])
ax[1].set_xticklabels(context)
ax[1].set_title("SIM for all models with face feature")
ax[1].legend([model[i] for i in [1,3,5,8,10,12,14]], loc='best');

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), sharey='row')

ax[0].plot(ig_table[:, [0,2,4,7,9,11,13,6]])
ax[0].set_xlim([0,6])
ax[0].set_xticks([0,1,2,3,4])
ax[0].set_xticklabels(context)
ax[0].set_title("IG for all models without face feature")
ax[0].legend([model[i] for i in [0,2,4,7,9,11,13,6]], loc='best');

ax[1].plot(ig_table[:, [1,3,5,8,10,12,14]])
ax[1].set_xlim([0,6])
ax[1].set_xticks([0,1,2,3,4])
ax[1].set_xticklabels(context)
ax[1].set_title("IG for all models with face feature")
ax[1].legend([model[i] for i in [1,3,5,8,10,12,14]], loc='best');

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), sharey='row')

ax[0].plot(auc_table[:, [0,2,4,7,9,11,13,6]])
ax[0].set_xlim([0,6])
ax[0].set_xticks([0,1,2,3,4])
ax[0].set_xticklabels(context)
ax[0].set_title("AUC for all models without face feature")
ax[0].legend([model[i] for i in [0,2,4,7,9,11,13,6]], loc='best');

ax[1].plot(auc_table[:, [1,3,5,8,10,12,14]])
ax[1].set_xlim([0,6])
ax[1].set_xticks([0,1,2,3,4])
ax[1].set_xticklabels(context)
ax[1].set_title("AUC for all models with face feature")
ax[1].legend([model[i] for i in [1,3,5,8,10,12,14]], loc='best');

# %%
fig, ax = plt.subplots()
index = np.arange(0,7)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, auc_table[4, [0,2,4,7,9,11,13]], bar_width,
                 alpha=opacity,
                 color='b',
                 label='without faces')
 
rects2 = plt.bar(index + bar_width, auc_table[4, [1,3,5,8,10,12,14]], bar_width,
                 alpha=opacity,
                 color='g',
                 label='with faces')
 
plt.xlabel('context')
plt.ylabel('AUC')
plt.title('person context')
plt.xticks(index + bar_width, [model[i] for i in [0,2,4,7,9,11,13]])
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
index = np.arange(0,7)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, nss_table[2, [0,2,4,7,9,11,13]], bar_width,
                 alpha=opacity,
                 color='b',
                 label='without faces')
 
rects2 = plt.bar(index + bar_width, nss_table[2, [1,3,5,8,10,12,14]], bar_width,
                 alpha=opacity,
                 color='g',
                 label='with faces')
 
plt.xlabel('context')
plt.ylabel('NSS')
plt.title('person context')
plt.xticks(index + bar_width, [model[i] for i in [0,2,4,7,9,11,13]])
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
index = np.arange(0,7)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, ig_table[1, [0,2,4,7,9,11,13]], bar_width,
                 alpha=opacity,
                 color='b',
                 label='without faces')
 
rects2 = plt.bar(index + bar_width, ig_table[1, [1,3,5,8,10,12,14]], bar_width,
                 alpha=opacity,
                 color='g',
                 label='with faces')
 
plt.xlabel('context')
plt.ylabel('IG')
plt.title('person context')
plt.xticks(index + bar_width, [model[i] for i in [0,2,4,7,9,11,13]])
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
index = np.arange(0,7)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, sim_table[1, [0,2,4,7,9,11,13]], bar_width,
                 alpha=opacity,
                 color='b',
                 label='without faces')
 
rects2 = plt.bar(index + bar_width, sim_table[1, [1,3,5,8,10,12,14]], bar_width,
                 alpha=opacity,
                 color='g',
                 label='with faces')
 
plt.xlabel('context')
plt.ylabel('SIM')
plt.title('person context')
plt.xticks(index + bar_width, [model[i] for i in [0,2,4,7,9,11,13]])
plt.legend()
 
plt.tight_layout()
plt.show()
