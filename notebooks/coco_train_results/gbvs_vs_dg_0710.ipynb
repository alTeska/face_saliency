# %%
import os
os.chdir('./data')

import numpy as np
import pickle
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib

import pandas as pd
import seaborn as sns
from glob import glob

matplotlib.rcParams.update({'font.size': 15})

# %% [markdown]
# ## Load data

# %%
data = glob('*.csv')
data
# Out:
# ['AUC_std_face_05.csv',
#  'NSS_std_noface.csv',
#  'AUC_mean_face_07.csv',
#  'AUC_mean_cxt.csv',
#  'IG_mean_cxt.csv',
#  'IG_std_face_07.csv',
#  'NSS_mean_cxt.csv',
#  'SIM_mean_cxt.csv',
#  'SIM_std_noface.csv',
#  'AUC_mean_face_03.csv',
#  'SIM_mean_face_03.csv',
#  'AUC_mean_models.csv',
#  'SIM_std_face_03.csv',
#  'NSS_std_face_05.csv',
#  'NSS_mean_face_07.csv',
#  'SIM_mean_face_05.csv',
#  'SIM_std_face_05.csv',
#  'AUC_std_noface.csv',
#  'SIM_mean_models.csv',
#  'NSS_std_face_07.csv',
#  'SIM_mean_noface.csv',
#  'IG_mean_noface.csv',
#  'IG_std_face_03.csv',
#  'AUC_std_face_03.csv',
#  'NSS_mean_models.csv',
#  'SIM_mean_face_07.csv',
#  'IG_std_face_05.csv',
#  'IG_mean_face_03.csv',
#  'IG_mean_face_07.csv',
#  'NSS_mean_face_05.csv',
#  'SIM_std_face_07.csv',
#  'AUC_mean_face_05.csv',
#  'AUC_std_face_07.csv',
#  'IG_mean_models.csv',
#  'IG_mean_face_05.csv',
#  'IG_std_noface.csv',
#  'NSS_std_face_03.csv',
#  'NSS_mean_face_03.csv',
#  'AUC_mean_noface.csv',
#  'NSS_mean_noface.csv']

# %%
for D in data:
    globals()[D[:-4]] = pd.read_csv(D, index_col=[0])

# %% [markdown]
# ## Get DG

# %%
dg_mean = pd.DataFrame(data=[AUC_mean_noface.loc['dg'],
                             SIM_mean_noface.loc['dg'],
                             NSS_mean_noface.loc['dg'],
                             IG_mean_noface.loc['dg']],
                       index=['auc', 'sim', 'nss', 'ig'])

# %%
dg_mean
# Out:
#           all    person  no person    animal    sports  electronic
# auc  0.774691  0.785386   0.754710  0.782197  0.802257    0.770191
# sim  0.650369  0.639309   0.671034  0.631222  0.641099    0.633137
# nss  1.149773  1.228926   1.001891  1.282687  1.357659    1.140596
# ig   3.623762  3.402096   4.037908  3.471155  2.748590    3.844617

# %%
dg_std = pd.DataFrame(data=[AUC_std_noface.loc['dg'],
                           SIM_std_noface.loc['dg'],
                           NSS_std_noface.loc['dg'],
                           IG_std_noface.loc['dg']],
                      index=['auc', 'sim', 'nss', 'ig'])
dg_std
# Out:
#           all    person  no person    animal    sports  electronic
# auc  0.093391  0.090612   0.095205  0.094686  0.086958    0.089656
# sim  0.085437  0.085112   0.082143  0.090368  0.094987    0.080914
# nss  0.789276  0.822800   0.698865  0.866592  0.860417    0.776124
# ig   3.395706  3.503344   3.143259  3.304526  4.072992    3.241242

# %% [markdown]
# ## Get GBVS

# %%
gbvs_auc_mean = pd.DataFrame(data=[AUC_mean_noface.loc['gbvs'],
                                   AUC_mean_face_03.loc['gbvs'],
                                   AUC_mean_face_05.loc['gbvs'],
                                   AUC_mean_face_07.loc['gbvs']],
                             index=[0, 0.3, 0.5, 0.7])


gbvs_auc_std = pd.DataFrame(data=[AUC_std_noface.loc['gbvs'],
                                 AUC_std_face_03.loc['gbvs'],
                                 AUC_std_face_05.loc['gbvs'],
                                 AUC_std_face_07.loc['gbvs']],
                            index=[0, 0.3, 0.5, 0.7])

# %%
gbvs_auc_mean
# Out:
#           all    person  no person    animal    sports  electronic
# 0.0  0.749366  0.756851   0.735382  0.754977  0.780210    0.744469
# 0.3  0.751947  0.760785   0.735434  0.755935  0.781719    0.747994
# 0.5  0.752648  0.761860   0.735436  0.756197  0.782176    0.748975
# 0.7  0.752909  0.762269   0.735422  0.756329  0.782433    0.749367

# %%
gbvs_nss_mean = pd.DataFrame(data=[NSS_mean_noface.loc['gbvs'],
                                   NSS_mean_face_03.loc['gbvs'],
                                   NSS_mean_face_05.loc['gbvs'],
                                   NSS_mean_face_07.loc['gbvs']],
                             index=[0, 0.3, 0.5, 0.7])


gbvs_nss_std = pd.DataFrame(data=[NSS_std_noface.loc['gbvs'],
                                 NSS_std_face_03.loc['gbvs'],
                                 NSS_std_face_05.loc['gbvs'],
                                 NSS_std_face_07.loc['gbvs']],
                            index=[0, 0.3, 0.5, 0.7])

# %%
gbvs_nss_mean
# Out:
#           all    person  no person    animal    sports  electronic
# 0.0  0.936297  0.977846   0.858669  0.976046  1.158277    0.895368
# 0.3  0.957663  1.010493   0.858960  0.983822  1.173559    0.926406
# 0.5  0.975387  1.037723   0.858924  0.990419  1.186663    0.952528
# 0.7  0.988806  1.058740   0.858146  0.995142  1.197292    0.972722

# %%
gbvs_ig_mean = pd.DataFrame(data=[IG_mean_noface.loc['gbvs'],
                                   IG_mean_face_03.loc['gbvs'],
                                   IG_mean_face_05.loc['gbvs'],
                                   IG_mean_face_07.loc['gbvs']],
                             index=[0, 0.3, 0.5, 0.7])


gbvs_ig_std = pd.DataFrame(data=[IG_std_noface.loc['gbvs'],
                                 IG_std_face_03.loc['gbvs'],
                                 IG_std_face_05.loc['gbvs'],
                                 IG_std_face_07.loc['gbvs']],
                            index=[0, 0.3, 0.5, 0.7])

# %%
gbvs_sim_mean = pd.DataFrame(data=[SIM_mean_noface.loc['gbvs'],
                                   SIM_mean_face_03.loc['gbvs'],
                                   SIM_mean_face_05.loc['gbvs'],
                                   SIM_mean_face_07.loc['gbvs']],
                             index=[0, 0.3, 0.5, 0.7])


gbvs_sim_std = pd.DataFrame(data=[SIM_std_noface.loc['gbvs'],
                                 SIM_std_face_03.loc['gbvs'],
                                 SIM_std_face_05.loc['gbvs'],
                                 SIM_std_face_07.loc['gbvs']],
                            index=[0, 0.3, 0.5, 0.7])

# %% [markdown]
# ### Covsal

# %%
covsal_mean = pd.DataFrame(data=[AUC_mean_noface.loc['covsal'],
                                 SIM_mean_noface.loc['covsal'],
                                 NSS_mean_noface.loc['covsal'],
                                 IG_mean_noface.loc['covsal']],
                             index=['auc', 'sim', 'nss', 'ig'])

# %% [markdown]
# ### ICF

# %%
icf_mean = pd.DataFrame(data=[AUC_mean_noface.loc['icf'],
                                 SIM_mean_noface.loc['icf'],
                                 NSS_mean_noface.loc['icf'],
                                 IG_mean_noface.loc['icf']],
                             index=['auc', 'sim', 'nss', 'ig'])

# %% [markdown]
# ### Get Respective Arrays

# %%
def split_arrays_for_plot(df):
    df = df.transpose()
    gbvs = df[0]
    gbvs_f03 = df[0.3]
    gbvs_f05 = df[0.5]
    gbvs_f07 = df[0.7]
    
    return gbvs, gbvs_f03, gbvs_f05, gbvs_f07

# %%
auc_gbvs_m, auc_gbvs_f03_m, auc_gbvs_f05_m, auc_gbvs_f07_m = split_arrays_for_plot(gbvs_auc_mean)
auc_gbvs_s, auc_gbvs_f03_s, auc_gbvs_f05_s, auc_gbvs_f07_s = split_arrays_for_plot(gbvs_auc_std)

nss_gbvs_m, nss_gbvs_f03_m, nss_gbvs_f05_m, nss_gbvs_f07_m = split_arrays_for_plot(gbvs_nss_mean)
nss_gbvs_s, nss_gbvs_f03_s, nss_gbvs_f05_s, nss_gbvs_f07_s = split_arrays_for_plot(gbvs_nss_std)

sim_gbvs_m, sim_gbvs_f03_m, sim_gbvs_f05_m, sim_gbvs_f07_m = split_arrays_for_plot(gbvs_sim_mean)
sim_gbvs_s, sim_gbvs_f03_s, sim_gbvs_f05_s, sim_gbvs_f07_s = split_arrays_for_plot(gbvs_sim_std)

ig_gbvs_m, ig_gbvs_f03_m, ig_gbvs_f05_m, ig_gbvs_f07_m = split_arrays_for_plot(gbvs_ig_mean)
ig_gbvs_s, ig_gbvs_f03_s, ig_gbvs_f05_s, ig_gbvs_f07_s = split_arrays_for_plot(gbvs_ig_std)

# %%
dg_mean = dg_mean.transpose()
dg_std = dg_std.transpose()

# %%
covsal_mean = covsal_mean.transpose()
auc_covsal = covsal_mean['auc']
nss_covsal = covsal_mean['nss']
sim_covsal = covsal_mean['sim']
ig_covsal = covsal_mean['ig']

# %%
icf_mean = icf_mean.transpose()
auc_icf = icf_mean['auc']
nss_icf = icf_mean['nss']
sim_icf = icf_mean['sim']
ig_icf = icf_mean['ig']

# %%
auc_dg_m = dg_mean['auc']
auc_dg_s = dg_std['auc']

nss_dg_m = dg_mean['nss']
nss_dg_s = dg_std['nss']

sim_dg_m = dg_mean['sim']
sim_dg_s = dg_std['sim']

ig_dg_m = dg_mean['ig']
ig_dg_s = dg_std['ig']

# %% [markdown]
# ### Make Plots

# %%
t = np.arange(0,6)
d = 0.8
m = 8

# %%
plt.subplots(figsize=(12,8))

plt.plot(auc_gbvs_m, '-o', label='gbvs', linewidth=d, markersize=m, c='b');
plt.errorbar(t, auc_gbvs_m, auc_gbvs_s, linestyle='None', c='b', label=None, alpha=0.3)
plt.fill_between(t, auc_gbvs_m - auc_gbvs_s, auc_gbvs_m + auc_gbvs_s, color='b', alpha=0.1)

plt.plot(auc_gbvs_f07_m, '-o', label='gbvs_f07', linewidth=d, markersize=m, c='g');
plt.errorbar(t, auc_gbvs_f07_m, auc_gbvs_f07_s, linestyle='None', c='g', label=None, alpha=0.3)
plt.fill_between(t, auc_gbvs_f07_m - auc_gbvs_f07_s, auc_gbvs_f07_m + auc_gbvs_f07_s, color='g', alpha=0.1)



plt.plot(auc_dg_m, '-o', label='dg', linewidth=d, markersize=m, c='r');
plt.errorbar(t, auc_dg_m, auc_dg_s, linestyle='None', c='r', label=None, alpha=0.3)
plt.fill_between(t, auc_dg_m - auc_dg_s, auc_dg_m + auc_dg_s, color='b', alpha=0.1)

plt.plot(auc_covsal, '-o', label='covsal', alpha=0.5)
plt.plot(auc_icf, '-o', label='icf', alpha=0.5)

plt.grid()
plt.yticks(np.arange(0.6, 0.92, step=0.05))
plt.ylabel('AUC score')
plt.xlabel('context')
plt.legend();

plt.savefig('../plots/AUC_gbvs_performance.jpg', bbox_inches='tight', pad_inches=0)

# %%
plt.subplots(figsize=(12,8))

plt.plot(nss_gbvs_m, '-o', label='gbvs', linewidth=d, markersize=m, c='b');
plt.errorbar(t, nss_gbvs_m, nss_gbvs_s, linestyle='None', c='b', label=None, alpha=0.3)
plt.fill_between(t, nss_gbvs_m - nss_gbvs_s, nss_gbvs_m + nss_gbvs_s, color='b', alpha=0.1)

plt.plot(nss_gbvs_f07_m, '-o', label='gbvs_f07', linewidth=d, markersize=m, c='g');
plt.errorbar(t, nss_gbvs_f07_m, nss_gbvs_f07_s, linestyle='None', c='g', label=None, alpha=0.3)
plt.fill_between(t, nss_gbvs_f07_m - nss_gbvs_f07_s, nss_gbvs_f07_m + nss_gbvs_f07_s, color='g', alpha=0.1)

plt.plot(nss_dg_m, '-o', label='dg', linewidth=d, markersize=m, c='r');
plt.errorbar(t, nss_dg_m, nss_dg_s, linestyle='None', c='r', label=None, alpha=0.3)
plt.fill_between(t, nss_dg_m - nss_dg_s, nss_dg_m + nss_dg_s, color='b', alpha=0.1)

plt.plot(nss_covsal, '-o', label='covsal', alpha=0.5)
plt.plot(nss_icf, '-o', label='icf', alpha=0.5)

plt.grid()
plt.yticks(np.arange(0, 2.1, step=0.2))
plt.ylabel('NSS score')
plt.xlabel('context')
plt.legend();
plt.savefig('../plots/NSS_gbvs_performance.jpg', bbox_inches='tight', pad_inches=0)

# %%
plt.subplots(figsize=(12,8))

plt.plot(sim_gbvs_m, '-o', label='gbvs', linewidth=d, markersize=m, c='b');
plt.errorbar(t, sim_gbvs_m, sim_gbvs_s, linestyle='None', c='b', label=None, alpha=0.3)
plt.fill_between(t, sim_gbvs_m - sim_gbvs_s, sim_gbvs_m + sim_gbvs_s, color='b', alpha=0.1)

plt.plot(sim_gbvs_f07_m, '-o', label='gbvs_f07', linewidth=d, markersize=m, c='g');
plt.errorbar(t, sim_gbvs_f07_m, sim_gbvs_f07_s, linestyle='None', c='g', label=None, alpha=0.3)
plt.fill_between(t, sim_gbvs_f07_m - sim_gbvs_f07_s, sim_gbvs_f07_m + sim_gbvs_f07_s, color='g', alpha=0.1)

plt.plot(sim_dg_m, '-o', label='dg', linewidth=d, markersize=m, c='r');
plt.errorbar(t, sim_dg_m, sim_dg_s, linestyle='None', c='r', label=None, alpha=0.3)
plt.fill_between(t, sim_dg_m - sim_dg_s, sim_dg_m + sim_dg_s, color='b', alpha=0.1)


plt.plot(sim_covsal, '-o', label='covsal', alpha=0.5)
plt.plot(sim_icf, '-o', label='icf', alpha=0.5)

plt.grid()
plt.yticks(np.arange(0.35, 0.85, step=0.05))
plt.ylabel('SIM score')
plt.xlabel('context')
plt.legend();
plt.savefig('../plots/SIM_gbvs_performance.jpg', bbox_inches='tight', pad_inches=0)

# %%
plt.subplots(figsize=(12,8))

plt.plot(ig_gbvs_m, '-o', label='gbvs', linewidth=d, markersize=m, c='b');
plt.errorbar(t, ig_gbvs_m, ig_gbvs_s, linestyle='None', c='b', label=None, alpha=0.3)
plt.fill_between(t, ig_gbvs_m - ig_gbvs_s, ig_gbvs_m + ig_gbvs_s, color='b', alpha=0.1)

plt.plot(ig_gbvs_f07_m, '-o', label='gbvs_f07', linewidth=d, markersize=m, c='g');
plt.errorbar(t, ig_gbvs_f07_m, ig_gbvs_f07_s, linestyle='None', c='g', label=None, alpha=0.3)
plt.fill_between(t, ig_gbvs_f07_m - ig_gbvs_f07_s, ig_gbvs_f07_m + ig_gbvs_f07_s, color='g', alpha=0.1)

plt.plot(ig_dg_m, '-o', label='dg', linewidth=d, markersize=m, c='r');
plt.errorbar(t, ig_dg_m, ig_dg_s, linestyle='None', c='r', label=None, alpha=0.3)
plt.fill_between(t, ig_dg_m - ig_dg_s, ig_dg_m + ig_dg_s, color='b', alpha=0.1)

plt.plot(ig_covsal, '-o', label='covsal', alpha=0.5)
plt.plot(ig_icf, '-o', label='icf', alpha=0.5)

plt.grid()
plt.yticks(np.arange(-4, 9, step=1))
plt.ylabel('IG score')
plt.xlabel('context')
plt.legend();
plt.savefig('../plots/IG_gbvs_performance.jpg', bbox_inches='tight', pad_inches=0)
