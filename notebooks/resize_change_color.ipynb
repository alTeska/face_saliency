# %%
import os
import gc
import shutil
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from glob import glob
from tqdm import tqdm
from saliency_model.utils import normalize_saliency_map
from utils_analysis import save_plot_without_frames

# %%
path_inp = './data/redo/'
path = './data/redo/results/'
fnames = glob('./data/redo/*.jpg')

# %%
directories_inp = ['ik', 'aim', 'sun', 'covsal', 'gbvs']

# %%
fnames
# Out:
# ['./data/redo/COCO_test2014_000000002063.jpg']

# %%
for fname in tqdm(fnames):
    name = fname[12:]  # get just the name of the picture
    smap_face = mpimg.imread(fname)

    for direct in tqdm(directories_inp):
        fname_inp = path_inp + direct + '/' + name
        smap = mpimg.imread(fname_inp)
        print(fname_inp, smap.shape)

        plt.figure()
        plt.imshow(smap)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.22it/s]
# ./data/redo/ik/COCO_test2014_000000002063.jpg (369, 492, 3)
# ./data/redo/aim/COCO_test2014_000000002063.jpg (460, 620)
# ./data/redo/sun/COCO_test2014_000000002063.jpg (480, 640)
# ./data/redo/covsal/COCO_test2014_000000002063.jpg (480, 640)
# ./data/redo/gbvs/COCO_test2014_000000002063.jpg (480, 640)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])


gray = rgb2gray(smap_face)    
plt.imshow(gray, cmap=plt.get_cmap('gray'))
plt.show()

# %%
smap.shape
# Out:
# (480, 640)

# %%
plt.imshow(gray);

# %%
plt.imshow(smap);

# %%
plt.imshow(smap_face);

# %%
smap_face.shape
# Out:
# (369, 492, 3)

# %%
gray.shape
# Out:
# (369, 492)

# %%
smap.shape
# Out:
# (480, 640)

# %%
import cv2
 
img = cv2.imread(fname, cv2.IMREAD_UNCHANGED)

# %%
if np.size(smap.shape)==3:
    smap = rgb2gray(smap)    
if np.shape(smap) is not (369, 492):
    smap = cv2.resize(smap, (492, 369), interpolation = cv2.INTER_AREA)

# %%
resized = cv2.resize(smap, (492, 369), interpolation = cv2.INTER_AREA)

# %%
plt.imshow(resized)

# %%
resized.shape
# Out:
# (369, 492)
