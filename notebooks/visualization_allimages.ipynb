# %% [markdown]
# # visualize all

# %%
import os
os.chdir('../saliency_model/')

import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
(dg_gbvs07_person, context, model, metrics) = pickle.load(open( "results_dg_gbvs07_person.p", "rb"))
(dg_gbvs07_noperson, context, model, metrics) = pickle.load(open( "results_dg_gbvs07_noperson.p", "rb"))
(dg_gbvs07_all, context, model, metrics) = pickle.load(open( "results_dg_gbvs07_all.p", "rb"))

# %%
print(np.shape(dg_gbvs07_person[:,0,:]))
print(model)
# Out:
# (2, 309)
# ['dg', 'gbvs_face_07']

# %%
fig, ax = plt.subplots(figsize=(30,10))
ax.set_xlabel("images", fontsize=18)
ax.set_ylabel("AUC", fontsize=18)
ax.tick_params(labelsize=18)
plt.plot(dg_gbvs07_all[0,3,0:100].transpose(), marker='o')
plt.plot(dg_gbvs07_all[1,3,0:100].transpose(), marker='s')
ax.legend(['deepgaze', 'GBVS with faces'], fontsize=18);
